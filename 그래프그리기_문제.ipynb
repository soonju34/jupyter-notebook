# %% [markdown]
# ##### [실습] CSV 파일에서 읽어온 데이터 그려보기
#
# [비트코인 가격 데이터](https://finance.yahoo.com/quote/BTC-USD/history?period1=1410825600&period2=1645142400&interval=1mo&filter=history&frequency=1mo&includeAdjustedClose=true)를 빈도(Frequency)는 월별(Monthly), 기간(Time Period)은 최대(Max)로 적용(Apply) 후 다운로드(Download) 합니다.
# - 첫 줄은 그래프 그릴 때 사용하지 않습니다.
# - 날짜(Date)에서 2014-01와 같이 일(day)를 삭제해서 길이를 줄였습니다.
# - 수치 데이터는 읽어들인 후 자료형을 바꿔줘야 그릴 수 있습니다.
# - ```MultipleLocator(20)```를 사용했습니다.

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# 데이터 읽어오기
dates = []
highs = []
lows = []

with open("BTC-USD.csv") as f:
	while line := f.readline():
		splitted = line.split(",")
		dates.append(splitted[0])
		highs.append(splitted[2])
		lows.append(splitted[3])

#첫줄지우기 
del dates[0]
del highs[0]
del lows[0]

#자료형정리 
dates = list(map(lambda x:x[:-3], dates))
highs = list(map(float, highs))
lows = list(map(float, lows))

# 그래프 그리기
fig, ax = plt.subplots()
ax.plot(dates, highs, label="High")
ax.plot(dates, lows, label="Low")
ax.set_xlabel("Date")
ax.set_ylabel("Stock Price")
ax.set_title("Bitcoin USD")
ax.legend()
ax.xaxis.set_major_locator(MultipleLocator(20))

plt.show()

# %%
new_data2 = data.drop(['Open', 'Close', 'Adj Close', 'Volume'], axis = 1)
new_data2.head()
# Out:
#          Date        High         Low
# 0  2014-10-01  411.697998  289.295990
# 1  2014-11-01  457.092987  320.626007
# 2  2014-12-01  384.037994  304.231995
# 3  2015-01-01  320.434998  171.509995
# 4  2015-02-01  265.610992  212.014999

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
# %matplotlib inline
#csv 파일 읽어오기
data = pd.read_csv("BTC-USD.csv")
#자료형정리
new_data2 = data.drop(['Open', 'Close', 'Adj Close', 'Volume'], axis = 1)
Date = ['2014/10' , '2016/08', '2018/02', '2019/10', '2021/06']
new_data2.plot(y=['High', 'Low'],
                ylim=(0,70000), grid=True, 
               xlabel='Date', ylabel='Stock Price', title='bitcoin USD')
# Out:
# <AxesSubplot:title={'center':'bitcoin USD'}, xlabel='Date', ylabel='Stock Price'>

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# 데이터 읽어오기
dates = []
highs = []
lows = []

with open("BTC-USD.csv") as f:
    while True:
        line = f.readline()
        if not line: 
            break
        else:
            splitted = line.split(",")
            dates.append(splitted[0])
            highs.append(splitted[2])
            lows.append(splitted[3])

#첫줄지우기 
del dates[0]
del highs[0]
del lows[0]

#자료형정리 
dates = list(map(lambda x:x[:-3], dates))
highs = list(map(float, highs))
lows = list(map(float, lows))

# 그래프 그리기
fig, ax = plt.subplots()
ax.plot(dates, highs, label="High")
ax.plot(dates, lows, label="Low")
ax.set_xlabel("Date")
ax.set_ylabel("Stock Price")
ax.set_title("Bitcoin USD")
ax.legend()
ax.xaxis.set_major_locator(MultipleLocator(20))

plt.show()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# 데이터 읽어오기
dates = []
highs = []
lows = []

with open("BTC-USD.csv") as csv_file:
	csv_reader = csv.DictReader(csv_file, delimiter=',')

	for row in csv_reader:
		dates.append(row["Date"])
		highs.append(row["High"])
		lows.append(row["Low"])

#자료형정리 
dates = list(map(lambda x:x[:-3], dates))
highs = list(map(float, highs))
lows = list(map(float, lows))

# 그래프 그리기
fig, ax = plt.subplots()
ax.plot(dates, highs, label="High")
ax.plot(dates, lows, label="Low")
ax.set_xlabel("Date")
ax.set_ylabel("Stock Price")
ax.set_title("Bitcoin USD")
ax.legend()
ax.xaxis.set_major_locator(MultipleLocator(20))

plt.show()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# 데이터 읽어오기
dates = []
highs = []
lows = []

with open("BTC-USD.csv") as csv_file:
	csv_reader = csv.DictReader(csv_file, delimiter=',')

	for row in csv_reader:
		dates.append(row["Date"])
		highs.append(row["High"])
		lows.append(row["Low"])

#자료형정리 
dates = list(map(lambda x:x[:-3], dates))
highs = list(map(float, highs))
lows = list(map(float, lows))

# 그래프 그리기
fig, ax = plt.subplots()
ax.plot(dates, highs, label="High")
ax.plot(dates, lows, label="Low")
ax.set_xlabel("Date")
ax.set_ylabel("Stock Price")
ax.set_title("Bitcoin USD")
ax.legend()
ax.xaxis.set_major_locator(MultipleLocator(20))

plt.show()
